# %% [markdown]
# # Short Overview

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We will use NP and PD with capital lettes to make them pop to make sure we are not cheating later.

# %% [markdown]
# # Numpy

# %%
a = np.array([10, 20, 30, 40, 50])
b = np.arange(10, 0, -2)
c = np.array(list('abcde'))

# %%
print(c)
# Out:
# ['a' 'b' 'c' 'd' 'e']

# %%
a+b
# Out:
# array([20, 28, 36, 44, 52])

# %%
a+c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e200917bc55f> in <module>
# ----> 1 a+c
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')

# %%
aint = np.array([10, 20, 30, 40, 50])
afloat = np.array([10, 20, 30, 40., 50])
astr = np.array(list('abcde'))

# %% [markdown]
# Some types can work together

# %%
afloat + aint
# Out:
# array([ 20.,  40.,  60.,  80., 100.])

# %% [markdown]
# Some can't

# %%
aint + astr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-9f82d99cce10> in <module>
# ----> 1 aint + astr
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')

# %% [markdown]
# ## dtype

# %%
print(aint.dtype)
print(astr.dtype)
# Out:
# int64
# <U1

# %% [markdown]
# ## Aggregate

# %%
np.array([1,4,98]).sum()
# Out:
# 103
