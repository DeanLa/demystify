# %%
class B:
    def __init__(self, num):
        self.num = num
    def __str__(self):
        return str(self.num)
    __repr__ = __str__

# %%
b = B(5)
b
# Out:
# 5

# %%
class B(B):
    def twice(self):
        return self.num * 2

# %%
c=B(3)

# %%
c.twice()
# Out:
# 6

# %%
b.twice()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-8f825f7c56ce> in <module>
# ----> 1 b.twice()
#
# AttributeError: 'B' object has no attribute 'twice'

# %%
import pandas as pd
import numpy as np

# %%
d = {"a":["word1","word2","word3"],
"b":["word2","word3","word4",'word5']}
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2a98837ed31a> in <module>
#       1 d = {"a":["word1","word2","word3"],
#       2 "b":["word2","word3","word4",'word5']}
# ----> 3 pd.DataFrame(d)
#
# ~/anaconda3/envs/sentinel/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/sentinel/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# ...

# %% [markdown]
# # Numpy flags

# %%
import numpy as np

# %%
a = np.arange(10,).reshape(5,-1)
a
b = np.arange(10,).reshape(-1,5)

# %%
a.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
a = np.array([[1,3,5],[20,40,60],[44,55,66],[100,200,300]])
print(a.shape)
print(a.strides)
print(a.dtype)
a.flags
# Out:
# (4, 3)
# (24, 8)
# int64
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
b = a[::2]
b.flags
# Out:
#   C_CONTIGUOUS : False
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
c = a[[0,3]]
c.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
d = a[[True,False,True,False]]
d.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
d = a[[True,True,False,False]]
d.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
d.data.tolist()
# Out:
# [[1, 3, 5], [20, 40, 60]]

# %% [markdown]
# # Image

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load_image( infilename ) :
    img = Image.open( infilename )
    img.load()
    data = np.asarray( img, dtype="int32" )
    return data

# %%
img = load_image('rsrc/tbilisi.jpg')
img = -img + 255

# %%
img.shape
# Out:
# (342, 512, 3)

# %%
np.savetxt('tbilisi.npy' ,img.mean(axis=2))

# %%
fix, ax = plt.subplots(figsize=(16,9))
ax.imshow(img[:,:,],cmap='Greys')
